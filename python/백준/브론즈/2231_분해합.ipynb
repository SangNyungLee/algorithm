# %%
n = int(input())
num = 0
for i in range(1, n):
    newN = str(i)
    result = i
    for j in newN:
        result += int(j)
    if int(result) == n:
        num = i
        break
print(num)
# Out:
# 198
